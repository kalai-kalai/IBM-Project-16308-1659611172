# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
train_datagen=ImageDataGenerator(rescale=1./255,shear_range=0.2,zoom_range=0.2,horizontal_flip=True)
text_dataset=ImageDataGenerator(rescale=1./255)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(rescale= 1./255,horizontal_flip = True,vertical_flip = True,zoom_range = 0.2)
test_datagen = ImageDataGenerator(rescale= 1./255)

# %%
x_train = train_datagen.flow_from_directory(
    r'C:\Users\priya\Downloads\TRAIN_SET',
    target_size=(64, 64),batch_size=5,color_mode='rgb',class_mode='sparse')
# Out:
# Found 2626 images belonging to 1 classes.

# %%
x_test = test_datagen.flow_from_directory(
    r'C:\Users\priya\Downloads\TEST_SET',
    target_size=(64, 64),batch_size=5,color_mode='rgb',class_mode='sparse')
# Out:
# Found 1055 images belonging to 1 classes.

# %%
# !pip install opencv.python

# %%
pip install opencv-python
# Out:
# ...
#   Using cached opencv_python-4.6.0.66-cp36-abi3-win_amd64.whl (35.6 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2

# %%
#imread is used to read the image

# %%
img = cv2.imread("C:\Users\priya\Downloads\TEST_SET\TEST_SET\APPLES\3_100.jpg")
# Out:
#   Input In [19]
#     img = cv2.imread("C:\Users\priya\Downloads\TEST_SET\TEST_SET\APPLES\3_100.jpg")
#                                                                                   ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
img = cv2.imread(r"C:\Users\priya\Downloads\TEST_SET\TEST_SET\APPLES\3_100.jpg")

# %%
img
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
img.ndim
# Out:
# 3

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (100, 100, 3)

# %%
img_flag = cv2.imread(r"C:\Users\priya\Downloads\TEST_SET\TEST_SET\APPLES\3_100.jpg")

# %%
img_flag
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %%
plt.imshow(img_flag)

# %%
resized_img = cv2.resize(img,(200,200))

# %%
resized_img.shape
# Out:
# (200, 200, 3)

# %%
plt.imshow(resized_img)

# %%
cv_img = cv2.cvtColor(img,cv2.COLOR_BGR2YCR_CB)

# %%
plt.imshow(cv_img)

# %%
cv_img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(cv_img)

# %%
roi_img = img[50:280,35:150]
roi_img = img[10:40,35:150]

# %%
plt.imshow(roi_img)

# %%
roi_img = img[10:40,0:90]

# %%
plt.imshow(roi_img)

# %%
roi_img = img[0:90,10:40]

# %%
plt.imshow(roi_img)

# %%
img_bl = cv2.blur(img,(10,10))

# %%
plt.imshow(img_bl)

# %%
img_gbl = cv2.GaussianBlur(img,(5,5),0)

# %%
plt.imshow(img_gbl)

# %%
img_edge = cv2.Canny(img,230,350)

# %%
plt.imshow(img_edge)

# %%
thresh, thresh_img = cv2.threshold(img, 200, 255, cv2.THRESH_BINARY)

# %%
plt.imshow(thresh_img)

# %%
circle = cv2.circle(img,(300,200),60,(255,0,0),5)

# %%
plt.imshow(img)

# %%
rectangle = cv2.rectangle(img,(200,100),(400,300),(0,0,255),10)

# %%
plt.imshow(img)

# %%
line = cv2.line(img,(200,100),(400,300),(0,255,0),3)

# %%
plt.imshow(img)

# %%
line = cv2.line(img,(100,50),(200,150),(0,150,0),3)

# %%
plt.imshow(img)

# %%
line = cv2.line(img,(50,25),(100,75),(0,75,0),3)

# %%
plt.imshow(img)

# %%
text = cv2.putText(img,"Opencv",(50,25),cv2.FONT_HERSHEY_SIMPLEX,2,(100,100,100),5)

# %%
plt.imshow(img)
